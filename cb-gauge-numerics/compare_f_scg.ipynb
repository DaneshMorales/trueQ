# %%
import os, sys

# Make sure we're in the project root
os.chdir("/Users/danesh/Documents/GitHub/trueQ")

# Ensure project root is on sys.path
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

from config import *
from noise_models import *
from cer import *

# %%
def gauge_fidelity_comparison(simulator):
    dic_gauged = {}
    dic = {}
    gauge = gauge_unitaries(simulator)
    gauge_fidelities = gauge_fidelity(gauge)

    h_gauge_ptm = tqm.Superop.from_unitary(gauge[tq.Gate.h]).ptm
    cnot_gauge_ptm = tqm.Superop.from_unitary(gauge[tq.Gate.cx]).ptm
    i_gauge_ptm = tqm.Superop.from_unitary(gauge[tq.Gate.id]).ptm
    t_gauge_ptm = tqm.Superop.from_unitary(gauge[tq.Gate.t]).ptm
    gauge_ptms = {tq.Gate.h: h_gauge_ptm, tq.Gate.t: t_gauge_ptm, tq.Gate.cx: cnot_gauge_ptm, tq.Gate.id: i_gauge_ptm}
    for gate in gauge_ptms.keys():
        print(f"Calculating fidelities for {gate}")
        print(f"Gauge fidelity of {gate}: {gauge_fidelities[gate]}")
        fidelities_gauged = []
        fidelities = []
        for circuit in circs[gate]:
            ideal_unitary_matrix = tq.Simulator().operator(circuit=circuit).upgrade().mat()
            ideal_unitary_superop = tqm.Superop.from_rowstack(ideal_unitary_matrix) 
            ideal_unitary_ptm = ideal_unitary_superop.ptm
            ideal_gauged_ptm = gauge_ptms[gate].conj().T @ ideal_unitary_ptm @ gauge_ptms[gate]
            ideal_gauged_superop = tqm.Superop.from_ptm(ideal_gauged_ptm)
            noisy_unitary_matrix = simulator.operator(circuit=circuit).upgrade().mat()
            noisy_unitary_superop = tqm.Superop.from_rowstack(noisy_unitary_matrix) 
            proc_fid_gauge = (ideal_gauged_superop.adj @ noisy_unitary_superop).fidelity 
            proc_fid = (ideal_unitary_superop.adj @ noisy_unitary_superop).fidelity
            fidelities_gauged.append(proc_fid_gauge)
            fidelities.append(proc_fid)
            print("Randomization with", list(circuit[0].gates.values()), " has a difference of fidelities of: ", proc_fid - proc_fid_gauge )
        dic_gauged[gate] = sum(fidelities_gauged) / len(fidelities_gauged)
        dic[gate] = sum(fidelities) / len(fidelities)
        print("Average difference in fidelities for gate ", gate, " is: ", dic[gate]- dic_gauged[gate])

# %%
gauge_fidelity_comparison(sim_gate_ind[4][0])
# Out:
# CNOT gauge computed
# H gauge computed
# I gauge computed
# T gauge computed
# Calculating fidelities for Gate.h
# Gauge fidelity of Gate.h: 1.0000000000000002
# Randomization with [Gate.x]  has a difference of fidelities of:  4.440892098500626e-16
# Randomization with [Gate.y]  has a difference of fidelities of:  4.440892098500626e-16
# Randomization with [Gate.z]  has a difference of fidelities of:  4.440892098500626e-16
# Randomization with [Gate.id]  has a difference of fidelities of:  4.440892098500626e-16
# Average difference in fidelities for gate  Gate.h  is:  4.440892098500626e-16
# Calculating fidelities for Gate.t
# Gauge fidelity of Gate.t: 0.9999999999999996
# Randomization with [Gate.x]  has a difference of fidelities of:  1.5543122344752192e-15
# Randomization with [Gate.y]  has a difference of fidelities of:  1.5543122344752192e-15
# Randomization with [Gate.z]  has a difference of fidelities of:  1.5543122344752192e-15
# Randomization with [Gate.id]  has a difference of fidelities of:  1.5543122344752192e-15
# Randomization with [Gate.s]  has a difference of fidelities of:  1.5543122344752192e-15
# Randomization with [Gate.cliff8]  has a difference of fidelities of:  1.6653345369377348e-15
# Randomization with [Gate.cliff10]  has a difference of fidelities of:  1.6653345369377348e-15
# Randomization with [Gate.cliff11]  has a difference of fidelities of:  1.6653345369377348e-15
# Average difference in fidelities for gate  Gate.t  is:  1.3322676295501878e-15
# Calculating fidelities for Gate.cx
# Gauge fidelity of Gate.cx: 0.9999999999999998
# Randomization with [Gate.x, Gate.x]  has a difference of fidelities of:  2.220446049250313e-16
# Randomization with [Gate.x, Gate.y]  has a difference of fidelities of:  2.220446049250313e-16
# Randomization with [Gate.x, Gate.z]  has a difference of fidelities of:  2.220446049250313e-16
# Randomization with [Gate.x, Gate.id]  has a difference of fidelities of:  2.220446049250313e-16
# Randomization with [Gate.y, Gate.x]  has a difference of fidelities of:  2.220446049250313e-16
# Randomization with [Gate.y, Gate.y]  has a difference of fidelities of:  2.220446049250313e-16
# Randomization with [Gate.y, Gate.z]  has a difference of fidelities of:  2.220446049250313e-16
# Randomization with [Gate.y, Gate.id]  has a difference of fidelities of:  2.220446049250313e-16
# Randomization with [Gate.z, Gate.x]  has a difference of fidelities of:  1.1102230246251565e-16
# Randomization with [Gate.z, Gate.y]  has a difference of fidelities of:  1.1102230246251565e-16
# Randomization with [Gate.z, Gate.z]  has a difference of fidelities of:  1.1102230246251565e-16
# Randomization with [Gate.z, Gate.id]  has a difference of fidelities of:  1.1102230246251565e-16
# Randomization with [Gate.id, Gate.x]  has a difference of fidelities of:  1.1102230246251565e-16
# Randomization with [Gate.id, Gate.y]  has a difference of fidelities of:  1.1102230246251565e-16
# Randomization with [Gate.id, Gate.z]  has a difference of fidelities of:  1.1102230246251565e-16
# Randomization with [Gate.id, Gate.id]  has a difference of fidelities of:  1.1102230246251565e-16
# Average difference in fidelities for gate  Gate.cx  is:  3.3306690738754696e-16
# Calculating fidelities for Gate.id
# Gauge fidelity of Gate.id: 1.0
# Randomization with [Gate.x]  has a difference of fidelities of:  7.771561172376096e-16
# Randomization with [Gate.y]  has a difference of fidelities of:  7.771561172376096e-16
# Randomization with [Gate.z]  has a difference of fidelities of:  7.771561172376096e-16
# Randomization with [Gate.id]  has a difference of fidelities of:  7.771561172376096e-16
# Average difference in fidelities for gate  Gate.id  is:  7.771561172376096e-16

# %%
gauge_fidelity_comparison(sim_gate_dep[4][0])
# Out:
# CNOT gauge computed
# H gauge computed
# I gauge computed
# T gauge computed
# Calculating fidelities for Gate.h
# Gauge fidelity of Gate.h: 0.999726396747632
# Randomization with [Gate.x]  has a difference of fidelities of:  0.0011428685884582457
# Randomization with [Gate.y]  has a difference of fidelities of:  0.0013428454058805883
# Randomization with [Gate.z]  has a difference of fidelities of:  0.0012896807070547078
# Randomization with [Gate.id]  has a difference of fidelities of:  0.00036400711177630996
# Average difference in fidelities for gate  Gate.h  is:  0.0010348504532924352
# Calculating fidelities for Gate.t
# Gauge fidelity of Gate.t: 0.999950468119159
# Randomization with [Gate.x]  has a difference of fidelities of:  0.0012325816941670675
# Randomization with [Gate.y]  has a difference of fidelities of:  0.0012418332936695586
# Randomization with [Gate.z]  has a difference of fidelities of:  8.63991113740914e-05
# Randomization with [Gate.id]  has a difference of fidelities of:  1.830995848128847e-05
# Randomization with [Gate.s]  has a difference of fidelities of:  9.423213373338513e-05
# Randomization with [Gate.cliff8]  has a difference of fidelities of:  1.3713264593540053e-05
# Randomization with [Gate.cliff10]  has a difference of fidelities of:  0.001888755672122544
# Randomization with [Gate.cliff11]  has a difference of fidelities of:  0.001411270405313525
# Average difference in fidelities for gate  Gate.t  is:  0.0007483869416818889
# Calculating fidelities for Gate.cx
# Gauge fidelity of Gate.cx: 0.9994519693778843
# Randomization with [Gate.x, Gate.x]  has a difference of fidelities of:  0.002520524236526378
# Randomization with [Gate.x, Gate.y]  has a difference of fidelities of:  0.004334865197176407
# Randomization with [Gate.x, Gate.z]  has a difference of fidelities of:  0.0043748775988357025
# Randomization with [Gate.x, Gate.id]  has a difference of fidelities of:  0.002532176409407727
# Randomization with [Gate.y, Gate.x]  has a difference of fidelities of:  0.0025602705280561855
# Randomization with [Gate.y, Gate.y]  has a difference of fidelities of:  0.0043748775988359245
# Randomization with [Gate.y, Gate.z]  has a difference of fidelities of:  0.004414618882524812
# Randomization with [Gate.y, Gate.id]  has a difference of fidelities of:  0.0025721770869293614
# Randomization with [Gate.z, Gate.x]  has a difference of fidelities of:  0.0007188079957154425
# Randomization with [Gate.z, Gate.y]  has a difference of fidelities of:  0.002520524236525712
# Randomization with [Gate.z, Gate.z]  has a difference of fidelities of:  0.0025602705280556304
# Randomization with [Gate.z, Gate.id]  has a difference of fidelities of:  0.0007198012326881109
# Randomization with [Gate.id, Gate.x]  has a difference of fidelities of:  0.0007198012326879999
# Randomization with [Gate.id, Gate.y]  has a difference of fidelities of:  0.002532176409406839
# Randomization with [Gate.id, Gate.z]  has a difference of fidelities of:  0.0025721770869286953
# Randomization with [Gate.id, Gate.id]  has a difference of fidelities of:  0.0007208163077273566
# Average difference in fidelities for gate  Gate.cx  is:  0.0025467976605016984
# Calculating fidelities for Gate.id
# Gauge fidelity of Gate.id: 0.9997272029915076
# Randomization with [Gate.x]  has a difference of fidelities of:  0.0007262688628536518
# Randomization with [Gate.y]  has a difference of fidelities of:  0.0007262688628537628
# Randomization with [Gate.z]  has a difference of fidelities of:  0.0007262688628536518
# Randomization with [Gate.id]  has a difference of fidelities of:  1.1102230246251565e-15
# Average difference in fidelities for gate  Gate.id  is:  0.0005447016471405997

# %%
gauge_fidelity_comparison(sim_ZXZXZ[4][0])
# Out:
# CNOT gauge computed
# H gauge computed
# I gauge computed
# T gauge computed
# Calculating fidelities for Gate.h
# Gauge fidelity of Gate.h: 0.9994997246766257
# Randomization with [Gate.x]  has a difference of fidelities of:  5.246089683774713e-07
# Randomization with [Gate.y]  has a difference of fidelities of:  -0.0019495820359034521
# Randomization with [Gate.z]  has a difference of fidelities of:  4.741913882733151e-05
# Randomization with [Gate.id]  has a difference of fidelities of:  0.001997525783699272
# Average difference in fidelities for gate  Gate.h  is:  2.397187389791e-05
# Calculating fidelities for Gate.t
# Gauge fidelity of Gate.t: 0.9994975506160728
# Randomization with [Gate.x]  has a difference of fidelities of:  -0.001646060237329161
# Randomization with [Gate.y]  has a difference of fidelities of:  -0.00033292571998644327
# Randomization with [Gate.z]  has a difference of fidelities of:  0.0016560795183011567
# Randomization with [Gate.id]  has a difference of fidelities of:  0.0003429450009582169
# Randomization with [Gate.s]  has a difference of fidelities of:  0.0017562312723038431
# Randomization with [Gate.cliff8]  has a difference of fidelities of:  0.0002427220211311809
# Randomization with [Gate.cliff10]  has a difference of fidelities of:  -0.00023277396598375688
# Randomization with [Gate.cliff11]  has a difference of fidelities of:  -0.001746283217156197
# Average difference in fidelities for gate  Gate.t  is:  4.991834029910436e-06
# Calculating fidelities for Gate.cx
# Gauge fidelity of Gate.cx: 0.9989985996968174
# Randomization with [Gate.x, Gate.x]  has a difference of fidelities of:  -0.0019789570718122818
# Randomization with [Gate.x, Gate.y]  has a difference of fidelities of:  -0.0019656438655571984
# Randomization with [Gate.x, Gate.z]  has a difference of fidelities of:  9.410192963521524e-06
# Randomization with [Gate.x, Gate.id]  has a difference of fidelities of:  -3.903016600248499e-06
# Randomization with [Gate.y, Gate.x]  has a difference of fidelities of:  -0.0019722783603607352
# Randomization with [Gate.y, Gate.y]  has a difference of fidelities of:  -0.0019589652218298115
# Randomization with [Gate.y, Gate.z]  has a difference of fidelities of:  1.60888363467393e-05
# Randomization with [Gate.y, Gate.id]  has a difference of fidelities of:  2.7756951904711613e-06
# Randomization with [Gate.z, Gate.x]  has a difference of fidelities of:  2.7756924224631163e-06
# Randomization with [Gate.z, Gate.y]  has a difference of fidelities of:  1.6088826272686596e-05
# Randomization with [Gate.z, Gate.z]  has a difference of fidelities of:  0.001995098925445471
# Randomization with [Gate.z, Gate.id]  has a difference of fidelities of:  0.001981785790228563
# Randomization with [Gate.id, Gate.x]  has a difference of fidelities of:  -3.903024291651569e-06
# Randomization with [Gate.id, Gate.y]  has a difference of fidelities of:  9.410187781888624e-06
# Randomization with [Gate.id, Gate.z]  has a difference of fidelities of:  0.0019884202866283784
# Randomization with [Gate.id, Gate.id]  has a difference of fidelities of:  0.001975107073841298
# Average difference in fidelities for gate  Gate.cx  is:  7.081934166763837e-06
# Calculating fidelities for Gate.id
# Gauge fidelity of Gate.id: 0.9994999999583
# Randomization with [Gate.x]  has a difference of fidelities of:  -0.0019990001666331247
# Randomization with [Gate.y]  has a difference of fidelities of:  7.771561172376096e-16
# Randomization with [Gate.z]  has a difference of fidelities of:  0.001999000166634457
# Randomization with [Gate.id]  has a difference of fidelities of:  7.771561172376096e-16
# Average difference in fidelities for gate  Gate.id  is:  7.771561172376096e-16

# %%
gauge_fidelity_comparison(sim_ZXZXZ_tilted[4][0])
# Out:
# CNOT gauge computed
# H gauge computed
# I gauge computed
# T gauge computed
# Calculating fidelities for Gate.h
# Gauge fidelity of Gate.h: 0.9994944655935931
# Randomization with [Gate.x]  has a difference of fidelities of:  -0.000154995022278559
# Randomization with [Gate.y]  has a difference of fidelities of:  -0.0019299791281711665
# Randomization with [Gate.z]  has a difference of fidelities of:  0.00021398455379351145
# Randomization with [Gate.id]  has a difference of fidelities of:  0.0019816796968427086
# Average difference in fidelities for gate  Gate.h  is:  2.767252504665141e-05
# Calculating fidelities for Gate.t
# Gauge fidelity of Gate.t: 0.9994890497143931
# Randomization with [Gate.x]  has a difference of fidelities of:  -0.002071808029780464
# Randomization with [Gate.y]  has a difference of fidelities of:  -0.0008797233745779787
# Randomization with [Gate.z]  has a difference of fidelities of:  0.0015891286967604223
# Randomization with [Gate.id]  has a difference of fidelities of:  0.0003970440415578258
# Randomization with [Gate.s]  has a difference of fidelities of:  0.0018011810998395106
# Randomization with [Gate.cliff8]  has a difference of fidelities of:  0.00018484184083389366
# Randomization with [Gate.cliff10]  has a difference of fidelities of:  -0.0006676709714990015
# Randomization with [Gate.cliff11]  has a difference of fidelities of:  -0.0022840102305046184
# Average difference in fidelities for gate  Gate.t  is:  -0.00024137711592131517
# Calculating fidelities for Gate.cx
# Gauge fidelity of Gate.cx: 0.9989877826758173
# Randomization with [Gate.x, Gate.x]  has a difference of fidelities of:  -0.0023704352824214237
# Randomization with [Gate.x, Gate.y]  has a difference of fidelities of:  -0.0019486713062749628
# Randomization with [Gate.x, Gate.z]  has a difference of fidelities of:  2.2701521859902485e-05
# Randomization with [Gate.x, Gate.id]  has a difference of fidelities of:  -0.0004176929939290197
# Randomization with [Gate.y, Gate.x]  has a difference of fidelities of:  -0.0023546528193170158
# Randomization with [Gate.y, Gate.y]  has a difference of fidelities of:  -0.0019328807952057048
# Randomization with [Gate.y, Gate.z]  has a difference of fidelities of:  3.849203299965964e-05
# Randomization with [Gate.y, Gate.id]  has a difference of fidelities of:  -0.0004019105308863402
# Randomization with [Gate.z, Gate.x]  has a difference of fidelities of:  7.003169935737574e-06
# Randomization with [Gate.z, Gate.y]  has a difference of fidelities of:  0.00042973271382085176
# Randomization with [Gate.z, Gate.z]  has a difference of fidelities of:  0.0024058289978299285
# Randomization with [Gate.z, Gate.id]  has a difference of fidelities of:  0.0019644242493239705
# Randomization with [Gate.id, Gate.x]  has a difference of fidelities of:  -8.779293825478263e-06
# Randomization with [Gate.id, Gate.y]  has a difference of fidelities of:  0.0004139422034858953
# Randomization with [Gate.id, Gate.z]  has a difference of fidelities of:  0.0023900384875065184
# Randomization with [Gate.id, Gate.id]  has a difference of fidelities of:  0.001948641785559646
# Average difference in fidelities for gate  Gate.cx  is:  1.161138377869797e-05
# Calculating fidelities for Gate.id
# Gauge fidelity of Gate.id: 0.999496941733983
# Randomization with [Gate.x]  has a difference of fidelities of:  -0.001986234808642906
# Randomization with [Gate.y]  has a difference of fidelities of:  5.125368462977065e-09
# Randomization with [Gate.z]  has a difference of fidelities of:  0.001986239934011258
# Randomization with [Gate.id]  has a difference of fidelities of:  1.1102230246251565e-16
# Average difference in fidelities for gate  Gate.id  is:  2.562684175977381e-09
